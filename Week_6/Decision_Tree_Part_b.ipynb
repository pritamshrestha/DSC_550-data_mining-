# %%
# Pritam shrestha
# DSC550 - Data Mining
# Date: 07/08/2020
# Problem:1(Decision_Tree_for_max_depth_2_and_4)



import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics 
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
from sklearn import tree
# Out:
# C:\Users\pritam\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
# loading dataset and renaming the columns
col_names=['age', 'delivery_number', 'delivery_time', 'blood_pressure', 'heart_problem', 'caesarian']
df = pd.read_csv(r"C:\Users\pritam\Desktop\caesarian.csv", header=None, names=col_names, skiprows=1)

# %%
# checking dataset
df.head()
# Out:
#    age  delivery_number  delivery_time  blood_pressure  heart_problem  \
# 0   22                1              0               2              0
# 1   26                2              0               1              0
# 2   26                2              1               1              0
# 3   28                1              0               2              0
# 4   22                2              0               1              0
#
#    caesarian
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1

# %%
# Spliting dataset in features and target variable
feature_columns = ['age','delivery_number', 'delivery_time', 'blood_pressure', 'heart_problem']
# feature dataset
X = df[feature_columns] 
# Target dataset
y = df['caesarian']

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
model = DecisionTreeClassifier()

# Train Decision Tree Classifer
model =model.fit(X_train,y_train)

#cPredict the response for test dataset
y_pred =model.predict(X_test)

# %%
# Checking accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %%
# creating the decision tree using graphviz
import graphviz
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# displaying graph
Image(graph.create_png())

# %%
# for Depth=2

model1 = DecisionTreeClassifier(max_depth=2)

# fitting the model
model1 = model1.fit(X_train,y_train)

#Predicting 
y_pred_model1 = model1.predict(X_test)

# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_model1))


# creating graph for max_depth=2
dot_data = StringIO()
export_graphviz(model1, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# displaying graph
Image(graph.create_png())
# Out:
# Accuracy: 0.4166666666666667

# %%
# for Depth=4

model2 = DecisionTreeClassifier(max_depth=2)

# fitting the model
model2 = model2.fit(X_train,y_train)

#Predicting 
y_pred_model2 = model2.predict(X_test)

# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_model2))


# creating graph for max_depth=2
dot_data = StringIO()
export_graphviz(model2, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_columns,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# displaying graph
Image(graph.create_png())
# Out:
# Accuracy: 0.4166666666666667

# %%
# creating decision tree using another method
def plot(x):
    print("Decision Tree Plot For Model",x)
    tree.plot_tree(x,filled=True)
plot(model)
# Out:
# Decision Tree Plot For Model DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# If we increase max_depth,training error will always go down or it allows the tree to grow too.
